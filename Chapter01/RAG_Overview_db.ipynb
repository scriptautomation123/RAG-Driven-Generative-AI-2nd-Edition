# %% [markdown]
# # Introducing Naive, Advanced, and Modular RAG with Oracle
#
# **Copyright 2026, Denis Rothman**
#
# This notebook introduces Naïve, Advanced, and Modular RAG. It marks a revolutionary conceptual shift in Generative AI architecture: **MAS-RAG (Multi-Agent Systems for Retrieval Augmented Generation)**.
#
# ### The Revolutionary Conceptual Shift: Bringing AI to the Data
#
# Traditionally, RAG architectures required moving corporate data *out* of secure environments into external vector stores and processing engines. We are reversing this paradigm.
#
# | Feature | **Traditional RAG (The Old Way)** | **Oracle MAS-RAG (The New Way)** |
# | :--- | :--- | :--- |
# | **Data Movement** | Moves data **to** the AI (External Vector DBs) | Moves AI **to** the Data (Oracle Database 23ai) |
# | **Security** | High risk of leakage; data leaves trust boundary | **Zero Trust:** Data never leaves the database |
# | **Latency** | Network latency between Vector Store & App | **Real-time:** Vectors & Data coexist locally |
# | **Data Freshness** | Stale data (requires frequent re-indexing/ETL) | **Instant:** Updates are immediately retrievable |
# | **Architecture** | Fragmented (App + Vector DB + SQL DB) | **Converged:** Single engine for SQL, JSON, & Vectors |
#
# By implementing RAG directly within **Oracle**, we utilize **Oracle Database 23ai** capabilities. This ensures that the Multi-Agent Systems operate strictly within the corporate trust boundary, leveraging data where it lives securely.
#
# ---
#
# ### **Summary**
#
# **Part 1: Foundations and Basic Implementation**
# 1.  **Environment:** Setup for secure integration.
# 2.  **Generator:** Utilizing LLMs with corporate context.
# 3.  **The Data:** A simulated **Oracle Database** environment (simulated via `db_records`) illustrating Integrated Vector logic.
# 4.  **Query:** Asking strategic questions about data sovereignty and architecture.
#
# **Part 2: Advanced Techniques and Evaluation**
# 1.  Retrieval metrics
# 2.  Naive RAG
# 3.  Advanced RAG within Oracle
# 4.  Modular RAG Retriever

# %% [markdown]
# # Part 1: Foundations and Basic Implementation

# %% [markdown]
# # 1.The Environment

# %%
# !pip install google-generativeai

# %% [markdown]
# ## Retrieving API Key (Google Secrets)

# %%
# Cell 2: Imports and API Key Setup
# We will use the Google Generative AI library to interact with the LLM and Google Colab's
# secret manager to securely access your API key.

import google.generativeai as genai
from google.colab import userdata

# Load the API key from Colab secrets and configure the Gemini client
try:
    api_key = userdata.get("GEMINI_API_KEY")
    if not api_key:
        raise userdata.SecretNotFoundError("GEMINI_API_KEY not found.")

    genai.configure(api_key=api_key)
    print("Gemini API key loaded and configured successfully.")

except userdata.SecretNotFoundError:
    print('Secret "GEMINI_API_KEY" not found.')
    print('Please add your Gemini API key to the Colab Secrets Manager.')
except Exception as e:
    print(f"An error occurred while loading the API key: {e}")

# %% [markdown]
# # 2.The Generator

# %%
import google.generativeai as genai

gemini_model = "gemini-1.5-flash-latest"

def call_llm_with_full_text(itext):
    # Join all lines to form a single string
    text_input = '\n'.join(itext)
    prompt = f"Please elaborate on the following content:\n{text_input}"

    try:
        model = genai.GenerativeModel(
            model_name=gemini_model,
            system_instruction="You are an expert Natural Language Processing exercise expert.",
            generation_config=genai.types.GenerationConfig(temperature=0.1)
        )
        response = model.generate_content(prompt)
        return response.text.strip()
    except Exception as e:
        return str(e)

# %% [markdown]
# ## Formatted response

# %%
import textwrap

def print_formatted_response(response):
    # Define the width for wrapping the text
    wrapper = textwrap.TextWrapper(width=80)  # Set to 80 columns wide, but adjust as needed
    wrapped_text = wrapper.fill(text=response)

    # Print the formatted response with a header and footer
    print("Response:")
    print("---------------")
    print(wrapped_text)
    print("---------------\n")

# %% [markdown]
#  # 3.The Data simulating an Oracle db retrieval

# %%
db_records = [
    "Retrieval Augmented Generation (RAG) is a hybrid AI approach that combines neural language models with secure retrieval systems.",
    "The Oracle strategy for RAG represents a paradigm shift: instead of moving data to external vector stores, it brings AI vector search directly to the database.",
    "This methodology ensures that sensitive corporate data never leaves the secure governance boundary of the Oracle environment.",
    "At the core of this architecture is the Oracle Database 23ai, which integrates vector search natively alongside relational data.",
    "Unlike external platforms that require data replication (ETL), Oracle allows for 'Integrated Vectorization', meaning vectors and business data coexist in real-time.",
    "The retrieval system utilizes Oracle AI Vector Search to fetch contextually relevant documents without the latency of external API calls.",
    "When a query is received, the Oracle system performs a similarity search directly on the resident data, ensuring zero data leakage.",
    "This component merges the retrieval outputs with the generative model, ensuring the final response is grounded in the organization's single source of truth.",
    "By keeping data in Oracle, the system eliminates the complexity of synchronizing a separate vector database with the operational database.",
    "The integrator seamlessly incorporates the retrieved Oracle data into the final text output, enhancing accuracy and compliance.",
    "This approach is particularly critical for industries like finance, healthcare, and government where data sovereignty is non-negotiable.",
    "Oracle AI Vector Search supports various distance metrics and indexing methods tailored for high-performance corporate workloads.",
    "The Multi-Agent System (MAS) can now orchestrate complex tasks by querying the Oracle database directly for both structured (SQL) and unstructured (Vector) data.",
    "This response is influenced by real-time corporate data, making it far more accurate than models relying on stale, externally indexed data.",
    "Retrieval Augmented Generation (RAG) in Oracle adapts dynamically; as soon as a record is updated in the database, it is immediately available for retrieval.",
    "This eliminates the 'stale data' problem common in architectures that rely on external vector stores like Pinecone or FAISS.",
    "With access to the vast, secure repository of Oracle data, the RAG system provides nuanced answers grounded in the company's actual operational reality.",
    "The challenge of maintaining a separate, high-quality database of retrievable texts is solved by converging vectors and data into one Oracle platform.",
    "Furthermore, Oracle's robust security features (Row-Level Security, auditing) automatically apply to the vector retrieval process.",
    "In summary, Oracle-based RAG represents the maturity of AI: merging the best of generative technologies with the security and reliability of enterprise data systems.",
    "An Oracle Vector Store is not a separate silo; it is a capability of the converged database that treats vectors as a native data type."
]

# %%
import textwrap
paragraph = ' '.join(db_records)
wrapped_text = textwrap.fill(paragraph, width=80)
print(wrapped_text)
# Out:
# Retrieval Augmented Generation (RAG) is a hybrid AI approach that combines
# neural language models with secure retrieval systems. The Oracle strategy for
# RAG represents a paradigm shift: instead of moving data to external vector
# stores, it brings AI vector search directly to the database. This methodology
# ensures that sensitive corporate data never leaves the secure governance
# boundary of the Oracle environment. At the core of this architecture is the
# Oracle Database 23ai, which integrates vector search natively alongside
# relational data. Unlike external platforms that require data replication (ETL),
# Oracle allows for 'Integrated Vectorization', meaning vectors and business data
# coexist in real-time. The retrieval system utilizes Oracle AI Vector Search to
# fetch contextually relevant documents without the latency of external API calls.
# When a query is received, the Oracle system performs a similarity search
# directly on the resident data, ensuring zero data leakage. This component merges
# the retrieval outputs with the generative model, ensuring the final response is
# grounded in the organization's single source of truth. By keeping data in
# Oracle, the system eliminates the complexity of synchronizing a separate vector
# database with the operational database. The integrator seamlessly incorporates
# the retrieved Oracle data into the final text output, enhancing accuracy and
# compliance. This approach is particularly critical for industries like finance,
# healthcare, and government where data sovereignty is non-negotiable. Oracle AI
# Vector Search supports various distance metrics and indexing methods tailored
# for high-performance corporate workloads. The Multi-Agent System (MAS) can now
# orchestrate complex tasks by querying the Oracle database directly for both
# structured (SQL) and unstructured (Vector) data. This response is influenced by
# real-time corporate data, making it far more accurate than models relying on
# stale, externally indexed data. Retrieval Augmented Generation (RAG) in Oracle
# adapts dynamically; as soon as a record is updated in the database, it is
# immediately available for retrieval. This eliminates the 'stale data' problem
# common in architectures that rely on external vector stores like Pinecone or
# FAISS. With access to the vast, secure repository of Oracle data, the RAG system
# provides nuanced answers grounded in the company's actual operational reality.
# The challenge of maintaining a separate, high-quality database of retrievable
# texts is solved by converging vectors and data into one Oracle platform.
# Furthermore, Oracle's robust security features (Row-Level Security, auditing)
# automatically apply to the vector retrieval process. In summary, Oracle-based
# RAG represents the maturity of AI: merging the best of generative technologies
# with the security and reliability of enterprise data systems. An Oracle Vector
# Store is not a separate silo; it is a capability of the converged database that
# treats vectors as a native data type.

# %% [markdown]
# # 4.The Query

# %%
# A query designed to trigger the retrieval of "Integrated Vectorization" and "Data Sovereignty" concepts
query = "How does the Oracle RAG approach differ from traditional vector stores regarding data security?"

# %% [markdown]
# Generation without augmentation

# %%
# Call the function and print the result
llm_response = call_llm_with_full_text(query)
print_formatted_response(llm_response)
# Out:
# Response:
# ---------------
# Oracle’s RAG (Retrieval-Augmented Generation) approach differs from many
# “traditional” vector-store setups mainly in **where the data lives, how access
# is controlled, and how governance is enforced**. Here are the key security-
# related differences.  ## 1) Data stays inside the database security boundary
# **Traditional vector store pattern:**   Often involves exporting documents (or
# chunks) from an enterprise system into a separate vector database/service. That
# creates **another copy of sensitive data** (and embeddings) outside the primary
# governed system.  **Oracle RAG approach (typical):**   Vectors/embeddings and
# source text can be stored and queried **inside Oracle Database** (e.g., using
# Oracle’s vector capabilities). This keeps data within the **same security
# perimeter** as the rest of your enterprise data—reducing data sprawl and the
# risk introduced by additional systems.  ## 2) Uses mature database access
# controls (RBAC, VPD/FGAC, row-level security) **Traditional vector stores:**
# Many provide basic API keys, index-level permissions, or coarse tenant
# separation. Fine-grained controls (e.g., “user can see only rows for their
# region”) may require custom application logic.  **Oracle RAG approach:**
# Because retrieval happens in the database, you can apply **native Oracle
# security controls** to the retrieval step: - **Role-based access control
# (RBAC)** and privileges - **Row-level security** via **VPD/FGAC** (Virtual
# Private Database / Fine-Grained Access Control) - **Column-level controls** and
# masking policies (where applicable)  Result: the RAG retriever is less likely to
# “accidentally” fetch content the user shouldn’t see, because the database
# enforces it.  ## 3) Centralized auditing and compliance logging **Traditional
# vector stores:**   Audit trails may be limited or split across multiple systems
# (app logs + vector DB logs + storage logs). That complicates compliance and
# incident response.  **Oracle RAG approach:**   Oracle Database provides
# **centralized auditing** (who queried what, when, from where), which can be
# aligned with enterprise compliance requirements. This is especially important
# for regulated environments (finance, healthcare, government).  ## 4) Encryption
# and key management integrated with enterprise controls **Traditional vector
# stores:**   Encryption at rest/in transit may exist, but key management and
# integration with enterprise HSM/KMS policies can vary by vendor and deployment.
# **Oracle RAG approach:**   You can leverage Oracle’s established database
# encryption features and enterprise key management patterns (e.g., TDE-style
# approaches, depending on configuration), keeping encryption policy consistent
# across structured and unstructured/RAG data.  ## 5) Reduced “embedding leakage”
# risk through governance and minimization Embeddings can sometimes leak
# information (they’re not guaranteed to be irreversible).   **Traditional
# approach:** exporting text to an embedding pipeline + storing embeddings in a
# separate system increases exposure points.  **Oracle approach:** keeping the
# pipeline closer to the governed data store and applying database controls can
# reduce: - the number of places embeddings live - who can query them - how
# they’re audited  ## 6) Policy enforcement at retrieval time (not just at
# generation time) A common RAG failure mode is **over-retrieval**: the system
# retrieves sensitive chunks and then relies on the LLM prompt to “behave.”
# Oracle’s database-centric retrieval can enforce **security policies before
# retrieval results are returned**, which is stronger than trying to filter after
# the fact.  ---  ### In one sentence **Oracle’s RAG approach tends to emphasize
# “bring RAG to the data (inside the database)” rather than “move data to a
# separate vector store,” enabling stronger, database-native security controls
# like fine-grained access, auditing, and centralized governance.**  If you tell
# me your deployment style (Oracle DB on-prem, OCI, hybrid) and what you mean by
# “traditional vector store” (Pinecone, Milvus, FAISS, Elasticsearch, etc.), I can
# tailor the comparison more precisely.
# ---------------

# %% [markdown]
# # Part 2: Advanced Techniques and Evaluation

# %% [markdown]
# # 1.Retrieval Metrics

# %% [markdown]
# ## Cosine Similarity

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def calculate_cosine_similarity(text1, text2):
    # Use the default settings to match the book's explanation
    vectorizer = TfidfVectorizer()
    tfidf = vectorizer.fit_transform([text1, text2])
    similarity = cosine_similarity(tfidf[0:1], tfidf[1:2])
    return similarity[0][0]

# %% [markdown]
# ## Enhanced Similarity

# %%
import spacy
import nltk
nltk.download('wordnet')
from nltk.corpus import wordnet
from collections import Counter
import numpy as np

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def get_synonyms(word):
    synonyms = set()
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())
    return synonyms

def preprocess_text(text):
    doc = nlp(text.lower())
    lemmatized_words = []
    for token in doc:
        if token.is_stop or token.is_punct:
            continue
        lemmatized_words.append(token.lemma_)
    return lemmatized_words

def expand_with_synonyms(words):
    expanded_words = words.copy()
    for word in words:
        expanded_words.extend(get_synonyms(word))
    return expanded_words

def calculate_enhanced_similarity(text1, text2):
    # Preprocess and tokenize texts
    words1 = preprocess_text(text1)
    words2 = preprocess_text(text2)

    # Expand with synonyms
    words1_expanded = expand_with_synonyms(words1)
    words2_expanded = expand_with_synonyms(words2)

    # Count word frequencies
    freq1 = Counter(words1_expanded)
    freq2 = Counter(words2_expanded)

    # Create a set of all unique words
    unique_words = set(freq1.keys()).union(set(freq2.keys()))

    # Create frequency vectors
    vector1 = [freq1[word] for word in unique_words]
    vector2 = [freq2[word] for word in unique_words]

    # Convert lists to numpy arrays
    vector1 = np.array(vector1)
    vector2 = np.array(vector2)

    # Calculate cosine similarity
    cosine_similarity = np.dot(vector1, vector2) / (np.linalg.norm(vector1) * np.linalg.norm(vector2))

    return cosine_similarity
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %% [markdown]
# # 2.Naive RAG

# %% [markdown]
# ## Keyword search and matching

# %%
def find_best_match_keyword_search(query, db_records):
    best_score = 0
    best_record = None

    # Split the query into individual keywords
    query_keywords = set(query.lower().split())

    # Iterate through each record in db_records
    for record in db_records:
        # Split the record into keywords
        record_keywords = set(record.lower().split())

        # Calculate the number of common keywords
        common_keywords = query_keywords.intersection(record_keywords)
        current_score = len(common_keywords)

        # Update the best score and record if the current score is higher
        if current_score > best_score:
            best_score = current_score
            best_record = record

    return best_score, best_record

# Assuming 'query' and 'db_records' are defined in previous cells in your Colab notebook
best_keyword_score, best_matching_record = find_best_match_keyword_search(query, db_records)

print(f"Best Keyword Score: {best_keyword_score}")
print_formatted_response(best_matching_record)
# Out:
# Best Keyword Score: 5
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %% [markdown]
# ## Metrics

# %%
# Cosine Similarity
score = calculate_cosine_similarity(query, best_matching_record)
print(f"Best Cosine Similarity Score: {score:.3f}")
# Out:
# Best Cosine Similarity Score: 0.243

# %%
# Enhanced Similarity
response = best_matching_record
print(query,": ", response)
similarity_score = calculate_enhanced_similarity(query, response)
print(f"Enhanced Similarity:, {similarity_score:.3f}")
# Out:
# How does the Oracle RAG approach differ from traditional vector stores regarding data security? :  The Oracle strategy for RAG represents a paradigm shift: instead of moving data to external vector stores, it brings AI vector search directly to the database.
# Enhanced Similarity:, 0.503

# %% [markdown]
# ## Augmented input

# %%
augmented_input=query+ ": "+ best_matching_record

# %%
print_formatted_response(augmented_input)
# Out:
# Response:
# ---------------
# How does the Oracle RAG approach differ from traditional vector stores regarding
# data security?: The Oracle strategy for RAG represents a paradigm shift: instead
# of moving data to external vector stores, it brings AI vector search directly to
# the database.
# ---------------

# %% [markdown]
# ## Generation

# %%
# Call the function and print the result
llm_response = call_llm_with_full_text(augmented_input)
print_formatted_response(llm_response)
# Out:
# Response:
# ---------------
# Oracle’s RAG (Retrieval-Augmented Generation) approach differs from many
# traditional vector-store setups mainly in **where the vectors live and where
# retrieval happens**, and that has direct consequences for **data security and
# governance**.  ## Traditional vector-store pattern (common in many RAG stacks)
# In a typical architecture:  1. **Data is exported from the primary system of
# record** (often an enterprise database or document repository). 2. It is
# **chunked and embedded**. 3. The embeddings (and often some text/metadata) are
# **loaded into an external vector database/service**. 4. Applications query that
# external store for retrieval.  ### Security implications - **Data duplication
# and extra attack surface**: You now have another system holding sensitive
# representations of your data (embeddings + metadata, sometimes raw text). -
# **More places to secure**: IAM, encryption, network controls, backups, logging,
# patching, incident response—across multiple platforms. - **Governance drift**:
# Policies enforced in the main database (row-level security, fine-grained access
# control, auditing) may not automatically carry over to the vector store. -
# **Risk of leakage through embeddings/metadata**: Even if embeddings aren’t
# “plain text,” they can still reveal information, especially when paired with
# metadata or if text is stored alongside vectors.  ## Oracle’s RAG strategy (as
# described): “bring vector search to the database” Oracle’s approach is
# positioned as a **paradigm shift**: instead of moving data out to a separate
# vector store, Oracle aims to **run vector search inside the database where the
# data already resides**.  ### Security implications / benefits - **Data stays in
# the system of record**: Less need to copy sensitive content into another
# platform just to enable semantic retrieval. - **Unified access control**:
# Existing database security controls (authentication, authorization, roles,
# privileges, row/column-level controls) can be applied consistently to both:   -
# the original data, and     - the vector search operations over that data. -
# **Centralized auditing and compliance**: Queries, access patterns, and retrieval
# can be logged and audited using the database’s established mechanisms. -
# **Reduced integration risk**: Fewer connectors/pipelines moving data around
# means fewer opportunities for misconfiguration or accidental exposure. -
# **Simpler governance**: Retention policies, encryption-at-rest, key management,
# and backup policies can remain centralized.  ## In one sentence Traditional
# vector stores often require **exporting and duplicating data into a separate
# retrieval system**, while Oracle’s RAG approach emphasizes **keeping data in the
# database and bringing vector search to it**, which can strengthen security by
# reducing data movement and preserving existing database governance controls.  If
# you want, I can also map this to a concrete RAG flow (ingestion → embedding →
# indexing → retrieval → generation) and point out exactly where security controls
# typically break or remain intact in each approach.
# ---------------

# %% [markdown]
# # 3.Advanced RAG

# %% [markdown]
# ## 3.1.Vector search

# %% [markdown]
# ### Search function

# %%
def find_best_match(text_input, records):
    best_score = 0
    best_record = None
    for record in records:
        current_score = calculate_cosine_similarity(text_input, record)
        if current_score > best_score:
            best_score = current_score
            best_record = record
    return best_score, best_record

# %%
best_similarity_score, best_matching_record = find_best_match(query, db_records)

# %%
print_formatted_response(best_matching_record)
# Out:
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %% [markdown]
# ### Metrics

# %%
print(f"Best Cosine Similarity Score: {best_similarity_score:.3f}")
# Out:
# Best Cosine Similarity Score: 0.243

# %%
# Enhanced Similarity
response = best_matching_record
print(query,": ", response)
similarity_score = calculate_enhanced_similarity(query, best_matching_record)
print(f"Enhanced Similarity:, {similarity_score:.3f}")
# Out:
# How does the Oracle RAG approach differ from traditional vector stores regarding data security? :  The Oracle strategy for RAG represents a paradigm shift: instead of moving data to external vector stores, it brings AI vector search directly to the database.
# Enhanced Similarity:, 0.503

# %% [markdown]
# ### Augmented input

# %%
augmented_input=query+": "+best_matching_record

# %%
print_formatted_response(augmented_input)
# Out:
# Response:
# ---------------
# How does the Oracle RAG approach differ from traditional vector stores regarding
# data security?: The Oracle strategy for RAG represents a paradigm shift: instead
# of moving data to external vector stores, it brings AI vector search directly to
# the database.
# ---------------

# %% [markdown]
# ### Generation

# %%
# Call the function and print the result
llm_response = call_llm_with_full_text(augmented_input)
print_formatted_response(llm_response)
# Out:
# Response:
# ---------------
# Oracle’s RAG (Retrieval-Augmented Generation) approach differs from many
# traditional “external vector store” setups mainly in **where the vectors live
# and where retrieval happens**, which has direct consequences for **data security
# and governance**.  ## 1) “Bring AI to the data” vs. “Move data to the AI”
# **Traditional vector-store pattern** - You typically **extract documents** (or
# chunks) from your core systems (often a database), - **generate embeddings**,
# and - **push the text + embeddings** into a separate vector database/service.
# This creates an additional copy of potentially sensitive content outside the
# primary system of record.  **Oracle RAG strategy** - Oracle’s approach
# emphasizes **running vector search inside the database** (e.g., Oracle Database
# with vector capabilities), - so you **don’t need to export data** to an external
# vector store to enable semantic retrieval.  **Security implication:** fewer data
# copies and fewer places where sensitive data can leak.  ## 2) Reduced data
# exposure and attack surface When you move data to an external vector store, you
# introduce: - another platform to secure, - additional credentials/secrets, -
# network paths and integrations (ETL/ELT pipelines, connectors), - and often a
# different security model.  With Oracle’s “in-database” vector search: - the
# retrieval layer is **co-located with the data**, - and you avoid expanding the
# number of systems that hold sensitive content.  **Security implication:** a
# smaller attack surface and fewer integration points to harden.  ## 3) Reuse of
# mature database security controls Databases like Oracle typically already
# enforce: - **role-based access control (RBAC)**, - **row-level and column-level
# security**, - **auditing and logging**, - **encryption at rest and in transit**,
# - **data masking/redaction**, - and established compliance controls.  In an
# external vector store, you may need to **re-implement** or **approximate** these
# controls, and ensure they match your database policies.  **Security
# implication:** Oracle’s approach can apply existing, centralized governance
# policies directly to RAG retrieval.  ## 4) Better governance and compliance
# alignment A common compliance concern is: *“Where does regulated data live, and
# who can access it?”*  External vector stores can complicate: - data residency
# requirements, - retention policies, - deletion requests (e.g., “right to be
# forgotten”), - and audit trails across multiple systems.  Keeping retrieval in
# the database helps maintain: - a single authoritative location for sensitive
# data, - consistent lifecycle management, - and unified auditing.  **Security
# implication:** simpler compliance story and clearer accountability.  ## 5)
# Controlling what the model can retrieve In RAG, the biggest practical security
# risk is often **unauthorized retrieval** (the model surfacing content a user
# shouldn’t see).  If vector search is governed by the same database permissions
# as the underlying data, then: - retrieval results can be filtered by the user’s
# privileges, - and you can enforce “only retrieve what you’re allowed to read.”
# In external vector stores, teams sometimes accidentally index content broadly
# and rely on application-layer filtering, which is easier to misconfigure.
# **Security implication:** stronger, policy-consistent access enforcement at
# retrieval time.  ---  ### In one sentence Oracle’s RAG approach is a paradigm
# shift because it **brings vector search to the database**, reducing data
# movement and duplication, and allowing organizations to **apply existing
# database-grade security, access control, and auditing** directly to RAG
# retrieval—rather than securing a separate external vector store.  If you tell me
# which “traditional vector store” you’re comparing against (e.g., Pinecone,
# Weaviate, Elasticsearch, pgvector, etc.), I can tailor the comparison more
# precisely.
# ---------------

# %% [markdown]
# ## 3.2.Index-based search

# %% [markdown]
# ### Search Function

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

def setup_vectorizer(records):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(records)
    return vectorizer, tfidf_matrix

def find_best_match_indexed(query, vectorizer, tfidf_matrix):
    query_tfidf = vectorizer.transform([query])
    similarities = cosine_similarity(query_tfidf, tfidf_matrix)
    best_index = similarities.argmax()  # Get the index of the highest similarity score
    best_score = similarities[0, best_index]
    return best_score, best_index

vectorizer, tfidf_matrix = setup_vectorizer(db_records)

best_similarity_score, best_index = find_best_match_indexed(query, vectorizer, tfidf_matrix)
best_matching_record = db_records[best_index]

print_formatted_response(best_matching_record)
# Out:
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %% [markdown]
# ### Metrics

# %%
# Cosine Similarity
print(f"Best Cosine Similarity Score: {best_similarity_score:.3f}")
print_formatted_response(best_matching_record)
# Out:
# Best Cosine Similarity Score: 0.318
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %%
# Enhanced Similarity
response = best_matching_record
print(query,": ", response)
similarity_score = calculate_enhanced_similarity(query, response)
print(f"Enhanced Similarity:, {similarity_score:.3f}")
# Out:
# How does the Oracle RAG approach differ from traditional vector stores regarding data security? :  The Oracle strategy for RAG represents a paradigm shift: instead of moving data to external vector stores, it brings AI vector search directly to the database.
# Enhanced Similarity:, 0.503

# %% [markdown]
# Feature extraction

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

def setup_vectorizer(records):
    vectorizer = TfidfVectorizer()
    tfidf_matrix = vectorizer.fit_transform(records)

    # Convert the TF-IDF matrix to a DataFrame for display purposes
    tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out())

    # Display the DataFrame
    print(tfidf_df)

    return vectorizer, tfidf_matrix

vectorizer, tfidf_matrix = setup_vectorizer(db_records)
# Out:
#         23ai    access  accuracy  accurate    actual   adapts     agent  \
# 0   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 3   0.290558  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 6   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 7   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 8   0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 9   0.000000  0.000000  0.283723  0.000000  0.000000  0.00000  0.000000
# 10  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.243705
# 13  0.000000  0.000000  0.000000  0.246259  0.000000  0.00000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000  0.23564  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 16  0.000000  0.256397  0.000000  0.000000  0.256397  0.00000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 19  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000  0.00000  0.000000
#
#           ai    allows  alongside  ...    vector  vectorization   vectors  \
# 0   0.191764  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 1   0.170778  0.000000   0.000000  ...  0.265674       0.000000  0.000000
# 2   0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 3   0.000000  0.000000   0.290558  ...  0.152933       0.000000  0.000000
# 4   0.000000  0.249884   0.000000  ...  0.000000       0.249884  0.198909
# 5   0.186896  0.000000   0.000000  ...  0.145374       0.000000  0.000000
# 6   0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 7   0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 8   0.000000  0.000000   0.000000  ...  0.162957       0.000000  0.000000
# 9   0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 10  0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 11  0.191485  0.000000   0.000000  ...  0.148943       0.000000  0.000000
# 12  0.000000  0.000000   0.000000  ...  0.128273       0.000000  0.000000
# 13  0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 14  0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 15  0.000000  0.000000   0.000000  ...  0.145752       0.000000  0.000000
# 16  0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 17  0.000000  0.000000   0.000000  ...  0.000000       0.000000  0.207279
# 18  0.000000  0.000000   0.000000  ...  0.142491       0.000000  0.000000
# 19  0.164445  0.000000   0.000000  ...  0.000000       0.000000  0.000000
# 20  0.000000  0.000000   0.000000  ...  0.138498       0.000000  0.209456
#
#         when     where     which      with   without  workloads      zero
# 0   0.000000  0.000000  0.000000  0.191764  0.000000   0.000000  0.000000
# 1   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 3   0.000000  0.000000  0.290558  0.000000  0.000000   0.000000  0.000000
# 4   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 5   0.000000  0.000000  0.000000  0.000000  0.276196   0.000000  0.000000
# 6   0.282582  0.000000  0.000000  0.000000  0.000000   0.000000  0.282582
# 7   0.000000  0.000000  0.000000  0.167809  0.000000   0.000000  0.000000
# 8   0.000000  0.000000  0.000000  0.209501  0.000000   0.000000  0.000000
# 9   0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 10  0.000000  0.267668  0.000000  0.000000  0.000000   0.000000  0.000000
# 11  0.000000  0.000000  0.000000  0.000000  0.000000   0.282977  0.000000
# 12  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 13  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 14  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 15  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 16  0.000000  0.000000  0.000000  0.173499  0.000000   0.000000  0.000000
# 17  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 18  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 19  0.000000  0.000000  0.000000  0.164445  0.000000   0.000000  0.000000
# 20  0.000000  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
#
# [21 rows x 224 columns]

# %% [markdown]
# ### Augmented input

# %%
augmented_input=query+": "+best_matching_record

# %%
print_formatted_response(augmented_input)
# Out:
# Response:
# ---------------
# How does the Oracle RAG approach differ from traditional vector stores regarding
# data security?: The Oracle strategy for RAG represents a paradigm shift: instead
# of moving data to external vector stores, it brings AI vector search directly to
# the database.
# ---------------

# %% [markdown]
# ### Generation

# %%
# Call the function and print the result
llm_response = call_llm_with_full_text(augmented_input)
print_formatted_response(llm_response)
# Out:
# Response:
# ---------------
# Oracle’s RAG (Retrieval-Augmented Generation) approach differs from many
# traditional “external vector store” setups mainly in **where the vectors live
# and where retrieval happens**—and that has direct consequences for **data
# security, governance, and compliance**.  ## 1) “Bring AI to the data” vs. “Move
# data to the AI” **Traditional vector store pattern** - You typically **extract
# documents/data** from your core systems (often a database), - **chunk** them, -
# create **embeddings**, and - **store those embeddings + metadata (and sometimes
# the text itself)** in a separate vector database/service.  This means sensitive
# information is **copied** into another system, creating additional security and
# compliance surface area.  **Oracle RAG strategy** - Oracle’s framing is: **don’t
# move data out to an external vector store**. - Instead, you run **vector search
# inside the database** (where the data already resides).  **Security
# implication:** fewer copies of sensitive data and fewer places to secure.  ## 2)
# Reduced data duplication and fewer “leak paths” When you export data to an
# external vector store, you introduce: - extra storage locations (embeddings
# store, object storage, caches), - extra pipelines (ETL/ELT jobs, embedding
# services), - extra credentials and network paths.  Each of these can become a
# potential leak point.  With Oracle’s approach, the retrieval layer is **co-
# located with the governed data**, so you can often avoid replicating: - raw
# text, - sensitive metadata, - and derived representations (embeddings) outside
# the database boundary.  ## 3) Reuse of database-native security controls A major
# security difference is that database platforms typically already have mature
# controls such as: - **role-based access control (RBAC)**, - **row-level and
# column-level security**, - **fine-grained auditing**, - **encryption at rest and
# in transit**, - **data masking/redaction**, - **policy enforcement and
# logging**.  In an external vector store architecture, you must **re-implement or
# reconfigure** many of these controls in a second system—and ensure policies
# remain consistent across both.  With Oracle’s “vector search in the database,”
# you can more directly apply existing database security policies to: - who can
# query, - what rows/documents they can retrieve, - what fields can be exposed to
# the RAG prompt.  ## 4) Better governance and compliance alignment External
# vector stores can complicate compliance because you now have: - additional data
# processors/subprocessors, - cross-region replication concerns, -
# retention/deletion policy duplication (e.g., “right to be forgotten”), - harder
# lineage tracking (what data was embedded, when, and where it went).  Keeping
# retrieval in the database can simplify: - **data residency** (data stays where
# it is governed), - **auditability** (centralized logs), - **lifecycle
# management** (one place to delete/update).  ## 5) Embeddings are not “safe” just
# because they’re vectors A common misconception is that embeddings are harmless.
# In reality: - embeddings can still **encode sensitive information**, - they can
# sometimes be used for **membership inference** or reconstruction-style attacks,
# - metadata stored alongside vectors can directly reveal sensitive context.
# Oracle’s approach reduces the need to ship embeddings to a separate system,
# which can lower exposure.  ---  ### In one sentence **Traditional vector stores
# often require copying data (or derived embeddings) into a separate system,
# expanding the security perimeter; Oracle’s RAG approach emphasizes running
# vector search inside the database so existing database security, access
# controls, auditing, and governance apply without duplicating sensitive data.**
# If you tell me your current architecture (Oracle DB + which LLM + whether you
# use an external vector DB today), I can map these points to a concrete “before
# vs. after” security model.
# ---------------

# %% [markdown]
# # 4.Modular RAG
#
# Modular RAG can combine methods. For example:
#
# **keyword search**:Searches through each document to find the one that best matches the keyword(s).
#
# **vector search**: Searches through each document and calculates similarity.
#
# **indexed search**: Uses a precomputed index (TF-IDF matrix) to compute cosine similarities.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

class RetrievalComponent:
    def __init__(self, method='vector'):
        self.method = method
        if self.method == 'vector' or self.method == 'indexed':
            self.vectorizer = TfidfVectorizer()
            self.tfidf_matrix = None

    def fit(self, records):
      self.documents = records  # Initialize self.documents here
      if self.method == 'vector' or self.method == 'indexed':
        self.tfidf_matrix = self.vectorizer.fit_transform(records)

    def retrieve(self, query):
        if self.method == 'keyword':
            return self.keyword_search(query)
        elif self.method == 'vector':
            return self.vector_search(query)
        elif self.method == 'indexed':
            return self.indexed_search(query)

    def keyword_search(self, query):
        best_score = 0
        best_record = None
        query_keywords = set(query.lower().split())
        for index, doc in enumerate(self.documents):
            doc_keywords = set(doc.lower().split())
            common_keywords = query_keywords.intersection(doc_keywords)
            score = len(common_keywords)
            if score > best_score:
                best_score = score
                best_record = self.documents[index]
        return best_record

    def vector_search(self, query):
        query_tfidf = self.vectorizer.transform([query])
        similarities = cosine_similarity(query_tfidf, self.tfidf_matrix)
        best_index = similarities.argmax()
        return self.documents[best_index]

    def indexed_search(self, query):
        # Assuming the tfidf_matrix is precomputed and stored
        query_tfidf = self.vectorizer.transform([query])
        similarities = cosine_similarity(query_tfidf, self.tfidf_matrix)
        best_index = similarities.argmax()
        return self.documents[best_index]

# %% [markdown]
# ### Modular RAG Strategies

# %%
# Usage example
retrieval = RetrievalComponent(method='vector')  # Choose from 'keyword', 'vector', 'indexed'
retrieval.fit(db_records)
best_matching_record = retrieval.retrieve(query)

print_formatted_response(best_matching_record)
# Out:
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %% [markdown]
# ### Metrics

# %%
# Cosine Similarity
print(f"Best Cosine Similarity Score: {best_similarity_score:.3f}")
print_formatted_response(best_matching_record)
# Out:
# Best Cosine Similarity Score: 0.318
# Response:
# ---------------
# The Oracle strategy for RAG represents a paradigm shift: instead of moving data
# to external vector stores, it brings AI vector search directly to the database.
# ---------------

# %%
# Enhanced Similarity
response = best_matching_record
print(query,": ", response)
similarity_score = calculate_enhanced_similarity(query, response)
print("Enhanced Similarity:", similarity_score)
# Out:
# How does the Oracle RAG approach differ from traditional vector stores regarding data security? :  The Oracle strategy for RAG represents a paradigm shift: instead of moving data to external vector stores, it brings AI vector search directly to the database.
# Enhanced Similarity: 0.5031579073491305

# %% [markdown]
# ### Augmented Input

# %%
augmented_input=query+ " "+ best_matching_record

# %%
print_formatted_response(augmented_input)
# Out:
# Response:
# ---------------
# How does the Oracle RAG approach differ from traditional vector stores regarding
# data security? The Oracle strategy for RAG represents a paradigm shift: instead
# of moving data to external vector stores, it brings AI vector search directly to
# the database.
# ---------------

# %% [markdown]
# ### Generation

# %%
# Call the function and print the result
llm_response = call_llm_with_full_text(augmented_input)
print_formatted_response(llm_response)
# Out:
# Response:
# ---------------
# Oracle’s RAG approach differs from many traditional “external vector store”
# setups mainly in **where the vectors live and how security is enforced**.  ##
# Traditional vector-store pattern (common today) In many RAG architectures, you:
# 1. Extract documents from your primary system (often a database). 2. Generate
# embeddings. 3. **Copy** the text/chunks + embeddings into a **separate vector
# database/service**. 4. At query time, you retrieve from that external store and
# then pass results to the LLM.  ### Security implications - **Data duplication**:
# Sensitive content is replicated outside the system of record, increasing the
# attack surface. - **New security boundary**: You must secure *another* platform
# (network access, IAM, encryption, backups, logging, patching). - **Policy
# drift**: The external store may not enforce the same fine-grained controls as
# the source database (e.g., row-level security, column masking, tenant
# isolation). - **More integration risk**: ETL/ingestion pipelines, connectors,
# and sync jobs become additional points where data can leak or be misconfigured.
# ## Oracle’s RAG strategy (vector search inside the database) Oracle’s approach
# is described as a “paradigm shift” because it **brings AI vector search to the
# database** rather than moving data out to a separate vector store.  ### What
# changes for data security - **Data stays in the database (system of record)**:
# Instead of exporting content to an external vector store, embeddings and
# searchable representations can be managed where the data already resides. -
# **Reuse existing database security controls**: You can apply the same mature
# controls you already rely on for enterprise data, such as:   - Role-based access
# control and privileges   - Row-level/column-level security patterns   - Auditing
# and monitoring   - Encryption at rest/in transit   - Centralized governance and
# compliance processes - **Fewer copies, fewer places to protect**: Reduces the
# number of systems holding sensitive text and embeddings, lowering exposure and
# simplifying compliance. - **Consistent access enforcement at retrieval time**:
# Retrieval can be constrained by the same authorization rules that govern the
# underlying data, helping prevent “retrieval leakage” (users retrieving chunks
# they shouldn’t see).  ## Bottom line Traditional vector stores often require
# **moving and duplicating data** into a separate retrieval system, which
# introduces additional security and governance complexity. Oracle’s RAG approach
# aims to **keep data in the database and bring vector search to it**, allowing
# organizations to leverage existing database-grade security, auditing, and access
# controls while reducing the risk that comes from spreading sensitive data across
# multiple platforms.  If you share your current architecture (DB type, vector
# store, and how you handle permissions), I can map these differences to your
# specific security risks and controls.
# ---------------
